# %% [markdown]
# ## Visualizing Network Data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the required libraries
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create and draw simple path graph
G1 = nx.path_graph(8)
nx.draw(G1, with_labels = True)
plt.show()

# %%
# Create and draw star graph
G2 = nx.star_graph(10)
nx.draw(G2, with_labels = True)
plt.show()

# %%
# Create and draw complete graph
G3 = nx.complete_graph(10)
nx.draw(G3, with_labels = True)
plt.show()

# %% [markdown]
# ## Adjacency Matrix

# %%
# Create an empty graph with no nodes and no edges using the Graph() function
G4 = nx.Graph()

# Add multiple nodes to the graph using add_node_from
G4.add_nodes_from(['A', 'B', 'C', 'D'])

# Add multiple edges at once
G4.add_edges_from([('A', 'B'), ('A', 'C'), ('A', 'D')])

# %%
# Plot graph
nx.draw(G4, with_labels = True)
plt.show()

# %%
# Create adjacency matrix (returns a SciPy sparse matrix)
A = nx.adjacency_matrix(G4)
print(A.todense())
# Out:
# [[0 1 1 1]
#  [1 0 0 0]
#  [1 0 0 0]
#  [1 0 0 0]]

# %%
# Create an adjacency matrix (as a Numpy Matrix)
A_np = nx.to_numpy_matrix(G4)
A_np
# Out:
# matrix([[0., 1., 1., 1.],
#         [1., 0., 0., 0.],
#         [1., 0., 0., 0.],
#         [1., 0., 0., 0.]])

# %%
# Create an adjacency matrix (as a Pandas Dataframe)
A_pd = nx.to_pandas_adjacency(G4)
A_pd
# Out:
#      A    B    C    D
# A  0.0  1.0  1.0  1.0
# B  1.0  0.0  0.0  0.0
# C  1.0  0.0  0.0  0.0
# D  1.0  0.0  0.0  0.0

# %% [markdown]
# ## Incidence Matrix

# %%
# Create incidence matrix (returns a SciPy sparse matrix)
I = nx.incidence_matrix(G4)
print(I.todense())
# Out:
# [[1. 1. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# ## Additional Network Visualization Tools

# %%
# Import the required libraries for Nxviz
import nxviz as nv
